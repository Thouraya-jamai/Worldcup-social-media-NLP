# %%
import pandas as pd
worldcup2018=pd.read_csv(r"C:\Projects\worldcup-social-media-nlp\Data\worldcup2018_clean.csv",delimiter=',')
worldcup2022=pd.read_csv(r"C:\Projects\worldcup-social-media-nlp\Data\worldcup2022_clean.csv",delimiter=',')

# %%
worldcup2018.head(10)
# Out:
#                   Date               Source  \
# 0  2018-07-02 01:35:45  twitter for android
# 1  2018-07-02 01:35:44  twitter for android
# 2  2018-07-02 01:35:42  twitter for android
# 3  2018-07-02 01:35:41   twitter web client
# 4  2018-07-02 01:35:40  twitter for android
# 5  2018-07-02 01:35:40  twitter for android
# 6  2018-07-02 01:35:40   twitter for iphone
# 7  2018-07-02 01:35:40   twitter web client
# 8  2018-07-02 01:35:40  twitter for android
# 9  2018-07-02 01:35:40         twitter lite
#
#                                           Orig_Tweet  \
# 0  rt @squawka: only two goalkeepers have saved t...
# 1  rt @fcbarcelona: ?? @ivanrakitic scores the wi...
# 2  rt @javierfernandez: tonight we have big game....
# 3  we get stronger\r\nturn the music up now\r\nwe...
# 4  rt @squawka: only two goalkeepers have saved t...
# 5  rt @fifaworldcup: "we’re looking strong going ...
# 6  rt @shshshshshsh555: i'm happy for #russia win...
# 7  rt @fridacarrillo05: when you see me\r\nwhen w...
# 8  rt @fifaworldcup: kasper schmeichel takes the ...
# 9  rt @btsarmyna: .@bts_twt after 5 years\r\n1. g...
#
#                                                Tweet  Likes   RTs  \
# 0  only two goalkeepers have saved three penaltie...      0   477
# 1  scores the winning penalty to send into the qu...      0  1031
# 2                           tonight we have big game      0   488
# 3  we get stronger turn the music up now we got t...      0     0
# 4  only two goalkeepers have saved three penaltie...      0   477
# 5  we re looking strong going into the knockout s...      0   153
# 6  am happy for winning especially since you know...      0     4
# 7  when you see me when we feel the same feeling ...      0     1
# 8  kasper schmeichel takes the final award of the...      0  2199
# 9  after years global puma ambassador lg mobile a...      0  5146
#
#                                          Hashtags             Place
# 0                                worldcup,por,eng             accra
# 1                                        worldcup             bogor
# 2                                        worldcup               NaN
# 3  powerbyexo,worldcup,fifastadiumdj,xiuminleague  zapopan, jalisco
# 4                                worldcup,por,eng               NaN
# 5                                          bramex               NaN
# 6                                          russia     mount olympus
# 7  powerbyexo,worldcup,fifastadiumdj,xiuminleague        lima, peru
# 8                   manofthematch,croden,worldcup               NaN
# 9                                             NaN         meme city

# %%
worldcup2022.head(10)
# Out:
#    Unnamed: 0               Date Created  Number of Likes  \
# 0           0  2022-11-20 23:59:21+00:00                4
# 1           1  2022-11-20 23:59:01+00:00                3
# 2           2  2022-11-20 23:58:41+00:00                1
# 3           3  2022-11-20 23:58:33+00:00                1
# 4           4  2022-11-20 23:58:28+00:00                0
# 5           5  2022-11-20 23:57:32+00:00                0
# 6           6  2022-11-20 23:57:06+00:00                0
# 7           7  2022-11-20 23:57:05+00:00                0
# 8           8  2022-11-20 23:56:10+00:00                1
# 9           9  2022-11-20 23:56:08+00:00                0
#
#        Source of Tweet                                              Tweet  \
# 0      twitter web app  what are we drinking today @tucantribe \n@madb...
# 1   twitter for iphone  amazing @canadasocceren  #worldcup2022 launch ...
# 2   twitter for iphone  worth reading while watching #worldcup2022 htt...
# 3      twitter web app  golden maknae shinning bright\n\nhttps://t.co/...
# 4  twitter for android  if the bbc cares so much about human rights, h...
# 5  twitter for android  and like, will the mexican fans be able to scr...
# 6  twitter for android  look like a only me and the jamaican football ...
# 7  twitter for android  really? football on a monday morning at 9 and ...
# 8   twitter for iphone  as the world cup starts in qatar, it’s black a...
# 9   twitter for iphone  #worldcup2022 @itvsport &amp; @lfsystemmusic g...
#
#   Sentiment
# 0   neutral
# 1  positive
# 2  positive
# 3  positive
# 4  negative
# 5  negative
# 6   neutral
# 7  negative
# 8  positive
# 9  positive

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.nlp_preprocessing import clean_noise
import re

punct_rows = worldcup2018[worldcup2018['Orig_Tweet'].str.contains(r'[^\w\s]', regex=True, na=False)]
remove_orig_tweet_noise = punct_rows[['Orig_Tweet']].head(5).copy()

remove_orig_tweet_noise['cleaned_Orig_Tweet'] = remove_orig_tweet_noise['Orig_Tweet'].apply(clean_noise)

remove_orig_tweet_noise
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                           Orig_Tweet  \
# 0  rt @squawka: only two goalkeepers have saved t...
# 1  rt @fcbarcelona: ?? @ivanrakitic scores the wi...
# 2  rt @javierfernandez: tonight we have big game....
# 3  we get stronger\r\nturn the music up now\r\nwe...
# 4  rt @squawka: only two goalkeepers have saved t...
#
#                                   cleaned_Orig_Tweet
# 0  rt only two goalkeepers have saved three penal...
# 1  rt scores the winning penalty to send into the...
# 2               rt tonight we have big game worldcup
# 3  we get stronger turn the music up now we got t...
# 4  rt only two goalkeepers have saved three penal...

# %%
from src.nlp_preprocessing import clean_noise
qmark_rows = worldcup2018[worldcup2018['Hashtags'].str.contains(r'\?{2,}', regex=True, na=False)]
sample_noise = qmark_rows[['Hashtags']].head(5).copy()

sample_noise['cleaned_Hashtags'] = sample_noise['Hashtags'].apply(clean_noise)

sample_noise
# Out:
#                                               Hashtags  \
# 91                       fifastadiumdj,worldcup,exo,??
# 94        worldcup,fifastadiumdj,dafbama2018exo,??,exo
# 113                  exo,exo,??,fifastadiumdj,worldcup
# 132  powerbyexo,exo,??,fifastadiumdj,copa2018,worldcup
# 146  powerbyexo,exo,??,fifastadiumdj,copa2018,worldcup
#
#                                    cleaned_Hashtags
# 91                       fifastadiumdj worldcup exo
# 94        worldcup fifastadiumdj dafbama2018exo exo
# 113                  exo exo fifastadiumdj worldcup
# 132  powerbyexo exo fifastadiumdj copa2018 worldcup
# 146  powerbyexo exo fifastadiumdj copa2018 worldcup

# %%
from src.nlp_preprocessing import clean_noise
import re

punct_rows = worldcup2022[worldcup2022['Tweet'].str.contains(r'[^\w\s]', regex=True, na=False)]
sample_noise = punct_rows[['Tweet']].head(5).copy()

sample_noise['cleaned_Tweet'] = sample_noise['Tweet'].apply(clean_noise)

sample_noise
# Out:
#                                                Tweet  \
# 0  what are we drinking today @tucantribe \n@madb...
# 1  amazing @canadasocceren  #worldcup2022 launch ...
# 2  worth reading while watching #worldcup2022 htt...
# 3  golden maknae shinning bright\n\nhttps://t.co/...
# 4  if the bbc cares so much about human rights, h...
#
#                                        cleaned_Tweet
# 0            what are we drinking today worldcup2022
# 1  amazing worldcup2022 launch video shows how mu...
# 2          worth reading while watching worldcup2022
# 3  golden maknae shinning bright jeonjungkook jun...
# 4  if the bbc cares so much about human rights ho...

# %% [markdown]
# **Tokenization**

# %%
# Apply tokenization to worldcup2022 tweet column
from src.nlp_preprocessing import tokenization
tweet22_tokens = sample_noise['cleaned_Tweet'].iloc[4]  
tokens = tokenization(tweet22_tokens)  
print(tokens)
# Out:
# ['if', 'the', 'bbc', 'cares', 'so', 'much', 'about', 'human', 'rights', 'homosexual', 'rights', 'and', 'women', 'rights', 'then', 'why', 'not', 'say', 'these', 'before', 'the', 'opening', 'ceremony', 'why', 'are', 'they', 'saying', 'these', 'during', 'the', 'opening', 'ceremony', 'why', 'did', 'the', 'bbc', 'censor', 'the', 'worldcup2022', 'opening', 'ceremony']

# %%
# Apply tokenization to worldcup2018 orig_tweet column
from src.nlp_preprocessing import tokenization
orig_tweet_tokens = remove_orig_tweet_noise['cleaned_Orig_Tweet'].iloc[3]
tokens_orgTweet=tokenization(orig_tweet_tokens)
print(tokens_orgTweet)
# Out:
# ['we', 'get', 'stronger', 'turn', 'the', 'music', 'up', 'now', 'we', 'got', 'that', 'power', 'power', 'powerbyexo', 'worldcup', 'fifastadiumdj', 'xiuminleague']

# %% [markdown]
# **Stop_words Removal**

# %%
#StopWords removal on Worldcup2022
from src.nlp_preprocessing import stopwords_removal
filtred_tweet22=stopwords_removal(tokens)
print ("tweet before stop words removal",tokens)
print("tweet After stop words removal",filtred_tweet22)
# Out:
# tweet before stop words removal ['if', 'the', 'bbc', 'cares', 'so', 'much', 'about', 'human', 'rights', 'homosexual', 'rights', 'and', 'women', 'rights', 'then', 'why', 'not', 'say', 'these', 'before', 'the', 'opening', 'ceremony', 'why', 'are', 'they', 'saying', 'these', 'during', 'the', 'opening', 'ceremony', 'why', 'did', 'the', 'bbc', 'censor', 'the', 'worldcup2022', 'opening', 'ceremony']
# tweet After stop words removal ['bbc', 'cares', 'much', 'human', 'rights', 'homosexual', 'rights', 'women', 'rights', 'say', 'opening', 'ceremony', 'saying', 'opening', 'ceremony', 'bbc', 'censor', 'worldcup2022', 'opening', 'ceremony']

# %%
#StopWords removal on Worldcup2018
from src.nlp_preprocessing import stopwords_removal
filtred_orgtweet18=stopwords_removal(tokens_orgTweet)
print ("tweet before stop words removal",tokens_orgTweet)
print("tweet After stop words removal",filtred_orgtweet18)
# Out:
# tweet before stop words removal ['we', 'get', 'stronger', 'turn', 'the', 'music', 'up', 'now', 'we', 'got', 'that', 'power', 'power', 'powerbyexo', 'worldcup', 'fifastadiumdj', 'xiuminleague']
# tweet After stop words removal ['get', 'stronger', 'turn', 'music', 'got', 'power', 'power', 'powerbyexo', 'worldcup', 'fifastadiumdj', 'xiuminleague']

# %% [markdown]
# **lemmatization**

# %%
#worldcup2022
from src.nlp_preprocessing import lemmatization
lemmetized_tweet=lemmatization(filtred_tweet22)
print(lemmetized_tweet)
# Out:
# ['bbc', 'care', 'much', 'human', 'right', 'homosexual', 'right', 'woman', 'right', 'say', 'opening', 'ceremony', 'saying', 'opening', 'ceremony', 'bbc', 'censor', 'worldcup2022', 'opening', 'ceremony']

# %%
#worldcup2018
from src.nlp_preprocessing import lemmatization
lemmetized_tweet=lemmatization(filtred_orgtweet18)
print(lemmetized_tweet)
# Out:
# ['get', 'stronger', 'turn', 'music', 'got', 'power', 'power', 'powerbyexo', 'worldcup', 'fifastadiumdj', 'xiuminleague']

# %%
from src.nlp_preprocessing import preprocess_text
row_text=worldcup2018['Tweet'].iloc[10]
preprocessed_row=preprocess_text(row_text)
print(preprocessed_row)
# Out:
# ['idek', 'anymore', 'spain', 'portugal']
