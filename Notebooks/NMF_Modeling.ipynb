# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
#2022 World Cup
from src.NMF_pipeline import run_nmf_pipeline

(
    df,
    vec,
    model,
    W,
    H,
    topic_labels
) = run_nmf_pipeline(
    dataset_path=r"C:\Projects\worldcup-social-media-nlp\Data\Preprocessed_Data\worldcup2022.csv",
    n_topics=50
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
feature_names = vec.get_feature_names_out()

top_topics = df["dominant_topic"].value_counts().head(10)

for topic_idx, count in top_topics.items():

    topic = H[topic_idx]

    top_words = [
        feature_names[i]
        for i in topic.argsort()[-10:][::-1]
    ]

    print(f"\nTopic {topic_idx} (Count: {count})")
    print(top_words)
# Out:
# Topic 1 (Count: 1906)
# ['worldcup2022', 'keeper', 'fuck', 'going', 'rigged', 'got', 'well', 'sport', 'rigged worldcup2022', 'shit']
#
# Topic 15 (Count: 895)
# ['qatar', 'worldcup2022 qatar', 'qatar ecuador', 'host', 'qatar world', 'money', 'qatar qatar2022', 'cup qatar', 'qatar2022 qatar', 'qatar win']
#
# Topic 31 (Count: 742)
# ['football', 'football worldcup2022', 'soccer', 'fan', 'worldcup2022 football', 'football fan', 'love', 'sport', 'fifa', 'football soccer']
#
# Topic 10 (Count: 739)
# ['qatar2022', 'worldcup2022 qatar2022', 'qatar2022 worldcup2022', 'qatarworldcup2022 qatar2022', 'fifaworldcup qatar2022', 'qatar2022 qatar', 'qatar2022 qatarworldcup2022', 'qatar2022 qatecu', 'qatar qatar2022', 'qatar2022 fifaworldcup']
#
# Topic 49 (Count: 729)
# ['one', 'one worldcup2022', 'watch', 'player', 'best', 'watch worldcup2022', 'know', 'thing', 'see', 'country']
#
# Topic 47 (Count: 707)
# ['get', 'qatar get', 'going', 'bet', 'let get', 'hope', 'get worldcup2022', 'amp', '10', 'worldcup2022 get']
#
# Topic 34 (Count: 668)
# ['england', 'iran', 'tomorrow', 'england iran', 'england worldcup2022', 'group', 'wale', 'worldcup2022 england', 'usa', 'see']
#
# Topic 18 (Count: 631)
# ['worldcupqatar2022', 'worldcup2022 worldcupqatar2022', 'worldcupqatar2022 worldcup2022', 'worldcupqatar2022 worldcup', 'worldcup worldcupqatar2022', 'worldcupqatar2022 qatarworldcup2022', 'worldcup2022', 'worldcupqatar2022 qatar2022', 'worldcupqatar2022 fifaworldcup', 'worldcupqatar2022 fifaworldcup2022']
#
# Topic 3 (Count: 623)
# ['ceremony', 'opening', 'opening ceremony', 'ceremony worldcup2022', 'worldcup2022 opening', 'cup opening', 'bbc', '2022 opening', 'ceremony live', 'beautiful']
#
# Topic 48 (Count: 610)
# ['right', 'human', 'human right', 'right worldcup2022', 'amp', 'country', 'people', 'bbc', 'worker', 'watch']

# %%
import pandas as pd

rows = []

for topic_id, keywords in topic_labels.items():

    label_text = ", ".join(
        [kw for kw, score in keywords]
    )

    rows.append({
        "Topic": topic_id,
        "Label": label_text
    })

labels_df = pd.DataFrame(rows)

labels_df.head(20)
# Out:
#     Topic                                              Label
# 0      19  qatarworldcup2022, fifaworldcuponfox, fifaworl...
# 1       9  fifaworldcup, fifa, worldcup, qatarworldcup202...
# 2      30  fifaworldcup, bbcworldcup, fifa, soccer, worldcup
# 3      17  jungkookworldcup, jungkookatfifaworldcup, jung...
# 4      48       bbc, lgbtq, fifaworldcup, lgbt, worldcup2026
# 5      46  qatarworldcup2022, qatar, fifaworldcup, fifa, ...
# 6      43  qatarworldcup, fifaworldcup, qatarworldcup2022...
# 7      31  worldcuppredictioncat, bbcworldcup, fifaworldc...
# 8      37  qatarworldcup, fifaworldcup, fifa, qatarworldc...
# 9      29  fifaworldcup, worldcup, worldcup2022, jungkook...
# 10     16  qatarworldcup2022, qatar, qatarvsecuador, ecua...
# 11     27  fifaworldcup, qatarworldcup2022, worldcupday, ...
# 12      5  qatarworldcup2022, fifaworldcup, worldcup2026,...
# 13      1  worldcup2022, cameroon, كأس_العالم_fifa, sport...
# 14      0  bbc, worldcup2010, worldcupbets, worldcupbetti...
# 15     33  qatarworldcup2022, qatar, qatari, qatar2022, fifa
# 16     42  qatarworldcup, qatarworldcup2022, qatar, fifaw...
# 17     36  fifaclubworldcup, fifaworldcup, fifawomensworl...
# 18     35    beinsports, tournament, xdb, telecast, cheering
# 19     11  qatarworldcup2022, qatarfans, fifaworldcup, qa...

# %%
#2018 World Cup
from src.NMF_pipeline import run_nmf_pipeline

(
    df,
    vec,
    model,
    W,
    H,
    topic_labels
) = run_nmf_pipeline(
    dataset_path=r"C:\Projects\worldcup-social-media-nlp\Data\Preprocessed_Data\worldcup2018.csv",
    n_topics=50
)

# %%
feature_names = vec.get_feature_names_out()

top_topics = df["dominant_topic"].value_counts().head(10)

for topic_idx, count in top_topics.items():

    topic = H[topic_idx]

    top_words = [
        feature_names[i]
        for i in topic.argsort()[-10:][::-1]
    ]

    print(f"\nTopic {topic_idx} (Count: {count})")
    print(top_words)
# Out:
# Topic 30 (Count: 5029)
# ['get', 'need', 'better', 'let', 'get better', 'let get', 'get back', 'england get', 'chance', 'get final']
#
# Topic 44 (Count: 4918)
# ['save', 'denmark', 'still', 'schmeichel', 'kasper', 'kasper schmeichel', 'keeper', 'goalkeeper', 'subasic', 'feel']
#
# Topic 4 (Count: 4472)
# ['croatia', 'denmark', 'croatia win', 'croatia denmark', 'france croatia', 'croatia england', 'england croatia', 'perisic', 'rakitic', 'denmark croatia']
#
# Topic 40 (Count: 3968)
# ['player', 'tournament', 'best player', 'player tournament', 'young', 'young player', 'player world', 'mbappe', 'hazard', 'kylian']
#
# Topic 6 (Count: 3743)
# ['game', 'great game', 'game today', 'beautiful', 'beautiful game', 'good game', 'win game', 'far', 'watching game', 'game far']
#
# Topic 13 (Count: 3459)
# ['time', 'extra', 'extra time', 'first time', 'last', 'full time', 'full', 'half time', 'last time', 'minute']
#
# Topic 48 (Count: 3293)
# ['watch', 'live', 'fan', 'watch game', 'soccer', 'tomorrow', 'watch live', 'tv', 'stream', 'video']
#
# Topic 8 (Count: 3264)
# ['win', 'france win', 'croatia win', 'win world', 'england win', 'want', 'win penalty', 'team win', 'think', 'win today']
#
# Topic 0 (Count: 3139)
# ['world', 'cup', 'world cup', 'cup final', 'win world', 'fifa world', 'best world', 'france world', 'cup semi', 'cup winner']
#
# Topic 5 (Count: 3123)
# ['final', 'semi', 'semi final', 'cup semi', 'first semi', 'final match', 'cup final', 'tomorrow', 'final france', 'make']

# %%
import pandas as pd

rows = []

for topic_id, keywords in topic_labels.items():

    label_text = ", ".join(
        [kw for kw, score in keywords]
    )

    rows.append({
        "Topic": topic_id,
        "Label": label_text
    })
    

labels_df = pd.DataFrame(rows)

labels_df.head(20)
# Out:
#     Topic                                              Label
# 0       3     penalty, ricardo, goalkeeper, shootout, keeper
# 1      25         penalty, croatia, worldcup, croatian, fifa
# 2      46               tonight, croatia, lovren, miami, nba
# 3      34                 power, turn, stronger, lyric, song
# 4      29    maradona, fifa, brazil, prediction, midfielders
# 5      33      spain, brazil, quarterfinal, croatia, penalty
# 6      44     schmeichel, goalkeeper, goalie, keeper, mbappe
# 7      19           worldcup, fifa, spain, catalonia, brasil
# 8      42       argentina, portugal, brazil, spain, maradona
# 9      43  coutinho, coutinhos, england, worldcup, schmei...
# 10     28           messi, goalkeeper, ronaldo, fifa, soccer
# 11     30        argentina, england, spain, portugal, brazil
# 12      6             cavani, napoli, mourinho, fifa, soccer
# 13     37           messi, ronaldo, cristiano, liga, vazquez
# 14     15          croatia, croatian, worldcup, soviet, fifa
# 15     20           goalkeeping, ramos, soccer, ball, keeper
# 16     31      quarterfinal, croatia, rythm, lebron, andreas
# 17      0            andres, mikel, midfielder, sergio, fifa
# 18     11               fifa, england, team, soccer, soldier
# 19      8           ronaldo, croatia, spain, brazil, england

# %%
import pickle

nmf_model18 = pickle.load(
    open(r"C:\Projects\worldcup-social-media-nlp\models\worldcup2018_nmf.pkl", "rb")
)

vectorizer18 = pickle.load(
    open(r"C:\Projects\worldcup-social-media-nlp\models\worldcup2018_vectorizer.pkl", "rb")
)

nmf_model22 = pickle.load(
    open(r"C:\Projects\worldcup-social-media-nlp\models\worldcup2022_nmf.pkl", "rb")
)

vectorizer22 = pickle.load(
    open(r"C:\Projects\worldcup-social-media-nlp\models\worldcup2022_vectorizer.pkl", "rb")
)

# %%
#2018 World Cup
feature_names = vectorizer18.get_feature_names_out()

for topic_idx, topic in enumerate(nmf_model18.components_[:10]):

    top_words = [
        feature_names[i]
        for i in topic.argsort()[-10:][::-1]
    ]

    print(f"Topic {topic_idx}: {top_words}")
# Out:
# Topic 0: ['world', 'cup', 'world cup', 'cup final', 'win world', 'fifa world', 'best world', 'france world', 'cup semi', 'cup winner']
# Topic 1: ['fifa', 'fifa world', 'champion', 'winner', 'fifa worldcup', 'live', 'france fifa', 'cup russia', 'moscow', 'round']
# Topic 2: ['coming', 'home', 'coming home', 'football coming', 'home coming', 'going home', 'england coming', 'go home', 'still coming', 'come home']
# Topic 3: ['penalty', 'shootout', 'penalty shootout', 'shoot', 'penalty shoot', 'kick', 'penalty kick', 'win penalty', 'dramatic', 'saved']
# Topic 4: ['croatia', 'denmark', 'croatia win', 'croatia denmark', 'france croatia', 'croatia england', 'england croatia', 'perisic', 'rakitic', 'denmark croatia']
# Topic 5: ['final', 'semi', 'semi final', 'cup semi', 'first semi', 'final match', 'cup final', 'tomorrow', 'final france', 'make']
# Topic 6: ['game', 'great game', 'game today', 'beautiful', 'beautiful game', 'good game', 'win game', 'far', 'watching game', 'game far']
# Topic 7: ['france', 'france win', 'france croatia', 'congrats', 'congratulation france', 'congrats france', 'france belgium', 'france final', 'france winning', 'france world']
# Topic 8: ['win', 'france win', 'croatia win', 'win world', 'england win', 'want', 'win penalty', 'team win', 'think', 'win today']
# Topic 9: ['england', 'come england', 'england win', 'croatia england', 'colombia', 'england fan', 'fan', 'england croatia', 'sweden', 'england need']

# %%
#2018 World Cup
import matplotlib.pyplot as plt

feature_names = vectorizer18.get_feature_names_out()

for topic_id in range(5):

    topic = nmf_model18.components_[topic_id]

    top_indices = topic.argsort()[-10:][::-1]

    words = [feature_names[i] for i in top_indices]
    weights = topic[top_indices]

    plt.figure(figsize=(8,5))
    plt.barh(words, weights)
    plt.title(f"NMF Topic {topic_id}")
    plt.gca().invert_yaxis()
    plt.show()

# %%
#2022 World Cup
import matplotlib.pyplot as plt

feature_names22 = vectorizer22.get_feature_names_out()

for topic_id in range(5):

    topic = nmf_model18.components_[topic_id]

    top_indices = topic.argsort()[-10:][::-1]

    words = [feature_names22[i] for i in top_indices]
    weights = topic[top_indices]

    plt.figure(figsize=(8,5))
    plt.barh(words, weights)
    plt.title(f"NMF Topic {topic_id}")
    plt.gca().invert_yaxis()
    plt.show()
