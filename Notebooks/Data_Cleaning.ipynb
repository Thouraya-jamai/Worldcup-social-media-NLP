# %%
import pandas as pd 
worldcup2018=pd.read_csv(r"C:\Projects\worldcup-social-media-nlp\Data\FIFA.csv",delimiter=',')
worldcup2022=pd.read_csv(r"C:\Projects\worldcup-social-media-nlp\Data\fifa_world_cup_2022_tweets.csv", delimiter=',')

# %% [markdown]
# # worldcup2018 dataset

# %%
worldcup2018.columns
# Out:
# Index(['ID', 'lang', 'Date', 'Source', 'len', 'Orig_Tweet', 'Tweet', 'Likes',
#        'RTs', 'Hashtags', 'UserMentionNames', 'UserMentionID', 'Name', 'Place',
#        'Followers', 'Friends'],
#       dtype='str')

# %%
common_ids = set(worldcup2018['ID']).intersection(set(worldcup2022['Unnamed: 0']))
print(len(common_ids))
# Out:
# 0

# %% [markdown]
# **Remove unecessary columns**

# %%
worldcup2018=worldcup2018.drop(columns=['Followers','Friends','lang','len','ID','Name'])

# %%
worldcup2018.columns
# Out:
# Index(['Date', 'Source', 'Orig_Tweet', 'Tweet', 'Likes', 'RTs', 'Hashtags',
#        'UserMentionNames', 'UserMentionID', 'Place'],
#       dtype='str')

# %%
worldcup2018.shape
# Out:
# (530000, 10)

# %%
worldcup2018.dtypes
# Out:
# Date                  str
# Source                str
# Orig_Tweet            str
# Tweet                 str
# Likes               int64
# RTs                 int64
# Hashtags              str
# UserMentionNames      str
# UserMentionID         str
# Place                 str
# dtype: object

# %% [markdown]
# **Correct Data Types**

# %%
#change the type of the column Date from str to datetime type
worldcup2018['Date']=pd.to_datetime(worldcup2018['Date'])
worldcup2018.dtypes
# Out:
# Date                datetime64[us]
# Source                         str
# Orig_Tweet                     str
# Tweet                          str
# Likes                        int64
# RTs                          int64
# Hashtags                       str
# UserMentionNames               str
# UserMentionID                  str
# Place                          str
# dtype: object

# %% [markdown]
# **Fix Empty Strings**

# %%
# Replace empty strings, spaces, or only question marks with NaN
import numpy as np
str_cols=worldcup2018.select_dtypes(include=str).columns
worldcup2018[str_cols] = worldcup2018[str_cols].replace(r'^\s*$|^\?+$', np.nan, regex=True)

# %%
(worldcup2018[str_cols].isnull().sum())
# Out:
# Source                   6
# Orig_Tweet               0
# Tweet                  551
# Hashtags             61543
# UserMentionNames     75344
# UserMentionID        74159
# Place               146553
# dtype: int64

# %%
empty_tweets = worldcup2018['Tweet'].isnull()
empty_tweets_count = worldcup2018['Tweet'].isnull().sum()
empty_hashtags_count = worldcup2018.loc[empty_tweets, 'Hashtags'].isnull().sum()
print("Number of empty Tweets is :", empty_tweets_count)
print("Number of empty hashtags when Tweet is empty:", empty_hashtags_count)
# Out:
# Number of empty Tweets is : 551
# Number of empty hashtags when Tweet is empty: 85

# %%
empty_tweet_rows = worldcup2018[empty_tweets]
missing_counts = empty_tweet_rows.isnull().sum()
print("Missing counts for each column when Tweet is empty:")
print(missing_counts)
# Out:
# Missing counts for each column when Tweet is empty:
# Date                  0
# Source                1
# Orig_Tweet            0
# Tweet               551
# Likes                 0
# RTs                   0
# Hashtags             85
# UserMentionNames     13
# UserMentionID        13
# Place               159
# dtype: int64

# %% [markdown]
# **Standardize text columns**

# %%
str_cols=worldcup2018.select_dtypes(include=str).columns
for col in str_cols:
    worldcup2018[col]= worldcup2018[col].str.strip().str.lower()

# %% [markdown]
# **Handle duplicants**

# %%
#chech duplicants
worldcup2018.duplicated().sum()
# Out:
# np.int64(4179)

# %%
# Show all duplicated rows
worldcup2018[worldcup2018.duplicated()]
# Out:
#                       Date               Source  \
# 1575   2018-07-02 01:21:54   Twitter for iPhone
# 1983   2018-07-02 01:18:18   Twitter for iPhone
# 2275   2018-07-02 01:15:31   Twitter for iPhone
# 3114   2018-07-02 01:08:18   Twitter for iPhone
# 3116   2018-07-02 01:08:18   Twitter for iPhone
# ...                    ...                  ...
# 529531 2018-07-15 22:49:58  Twitter for Android
# 529588 2018-07-15 22:49:52   Twitter for iPhone
# 529627 2018-07-15 22:49:48   Twitter for iPhone
# 529860 2018-07-15 22:49:25  Twitter for Android
# 529912 2018-07-15 22:49:20   Twitter for iPhone
#
#                                                Orig_Tweet  \
# 1575    RT @MisterHeartz: GG GN and GL #WorldCup https...
# 1983    RT @MisterHeartz: GG GN and GL #WorldCup https...
# 2275    RT @FIFAWorldCup: ?? | "Japan have never made ...
# 3114    RT @brfootball: A legend says goodbye to the #...
# 3116    RT @brfootball: A legend says goodbye to the #...
# ...                                                   ...
# 529531  RT @KhaledBeydoun: Dear France, \r\n\r\nCongra...
# 529588  RT @KhaledBeydoun: Dear France, \r\n\r\nCongra...
# 529627  RT @KhaledBeydoun: Dear France, \r\n\r\nCongra...
# 529860  RT @ajplus: France just won the #WorldCup \r\n...
# 529912  RT @KhaledBeydoun: Dear France, \r\n\r\nCongra...
#
#                                                     Tweet  Likes    RTs  \
# 1575                                         GG GN and GL      0   4370
# 1983                                         GG GN and GL      0   4370
# 2275    Japan have never made it past the last eight s...      0    221
# 3114                           legend says goodbye to the      0   5344
# 3116                           legend says goodbye to the      0   5344
# ...                                                   ...    ...    ...
# 529531  Dear France Congratulations on winning the of ...      0  96731
# 529588  Dear France Congratulations on winning the of ...      0  96731
# 529627  Dear France Congratulations on winning the of ...      0  96736
# 529860  France just won the of its teams players are i...      0  19569
# 529912  Dear France Congratulations on winning the of ...      0  96746
#
#         Hashtags               UserMentionNames                 UserMentionID  \
# 1575    WorldCup  HRK800 Serial No. 191 919 199                  MisterHeartz
# 1983    WorldCup  HRK800 Serial No. 191 919 199                  MisterHeartz
# 2275         NaN      FIFA World Cup ?,????????  FIFAWorldCup,jfa_samuraiblue
# 3114    WorldCup                   B/R Football                    brfootball
# 3116    WorldCup                   B/R Football                    brfootball
# ...          ...                            ...                           ...
# 529531  WorldCup                 Khaled Beydoun                 KhaledBeydoun
# 529588  WorldCup                 Khaled Beydoun                 KhaledBeydoun
# 529627  WorldCup                 Khaled Beydoun                 KhaledBeydoun
# 529860  WorldCup                            AJ+                        ajplus
# 529912  WorldCup                 Khaled Beydoun                 KhaledBeydoun
#
#         Place
# 1575      NaN
# 1983      NaN
# 2275      NaN
# 3114    India
# 3116    India
# ...       ...
# 529531    NaN
# 529588    NaN
# 529627    NaN
# 529860    NaN
# 529912    NaN
#
# [4179 rows x 10 columns]

# %%
#Remove duplicated rows
worldcup2018 = worldcup2018.drop_duplicates()

# %%
worldcup2018.duplicated().sum()
# Out:
# np.int64(0)

# %%
worldcup2018.head(10)
# Out:
#                  Date               Source  \
# 0 2018-07-02 01:35:45  twitter for android
# 1 2018-07-02 01:35:44  twitter for android
# 2 2018-07-02 01:35:42  twitter for android
# 3 2018-07-02 01:35:41   twitter web client
# 4 2018-07-02 01:35:40  twitter for android
# 5 2018-07-02 01:35:40  twitter for android
# 6 2018-07-02 01:35:40   twitter for iphone
# 7 2018-07-02 01:35:40   twitter web client
# 8 2018-07-02 01:35:40  twitter for android
# 9 2018-07-02 01:35:40         twitter lite
#
#                                           Orig_Tweet  \
# 0  rt @squawka: only two goalkeepers have saved t...
# 1  rt @fcbarcelona: ?? @ivanrakitic scores the wi...
# 2  rt @javierfernandez: tonight we have big game....
# 3  we get stronger\r\nturn the music up now\r\nwe...
# 4  rt @squawka: only two goalkeepers have saved t...
# 5  rt @fifaworldcup: "we’re looking strong going ...
# 6  rt @shshshshshsh555: i'm happy for #russia win...
# 7  rt @fridacarrillo05: when you see me\r\nwhen w...
# 8  rt @fifaworldcup: kasper schmeichel takes the ...
# 9  rt @btsarmyna: .@bts_twt after 5 years\r\n1. g...
#
#                                                Tweet  Likes   RTs  \
# 0  only two goalkeepers have saved three penaltie...      0   477
# 1  scores the winning penalty to send into the qu...      0  1031
# 2                           tonight we have big game      0   488
# 3  we get stronger turn the music up now we got t...      0     0
# 4  only two goalkeepers have saved three penaltie...      0   477
# 5  we re looking strong going into the knockout s...      0   153
# 6  am happy for winning especially since you know...      0     4
# 7  when you see me when we feel the same feeling ...      0     1
# 8  kasper schmeichel takes the final award of the...      0  2199
# 9  after years global puma ambassador lg mobile a...      0  5146
#
#                                          Hashtags  \
# 0                                worldcup,por,eng
# 1                                        worldcup
# 2                                        worldcup
# 3  powerbyexo,worldcup,fifastadiumdj,xiuminleague
# 4                                worldcup,por,eng
# 5                                          bramex
# 6                                          russia
# 7  powerbyexo,worldcup,fifastadiumdj,xiuminleague
# 8                   manofthematch,croden,worldcup
# 9                                             NaN
#
#                         UserMentionNames                      UserMentionID  \
# 0                       squawka football                            squawka
# 1    fc barcelona,ivan rakitic,hns | cff    fcbarcelona,ivanrakitic,hns_cff
# 2      javier fernandez,evgeni plushenko    javierfernandez,evgeniplushenko
# 3                   exo,fifa world cup ?           weareoneexo,fifaworldcup
# 4                       squawka football                            squawka
# 5  fifa world cup ?,cbf futebol,casemiro  fifaworldcup,cbf_futebol,casemiro
# 6                    v?deplorable?45  ??                    shshshshshsh555
# 7                         frida carrillo                    fridacarrillo05
# 8             fifa world cup ?,budweiser             fifaworldcup,budweiser
# 9            ???? & ???? ???? ™ ??,?????                  btsarmyna,bts_twt
#
#               Place
# 0             accra
# 1             bogor
# 2               NaN
# 3  zapopan, jalisco
# 4               NaN
# 5               NaN
# 6     mount olympus
# 7        lima, peru
# 8               NaN
# 9         meme city

# %% [markdown]
# **Save a clean copy**

# %%
worldcup2018.to_csv(r"C:\Projects\worldcup-social-media-nlp\Data\worldcup2018_clean.csv", index=False)

# %% [markdown]
# # worldcup2022 dataset

# %%
worldcup2022.columns
# Out:
# Index(['Unnamed: 0', 'Date Created', 'Number of Likes', 'Source of Tweet',
#        'Tweet', 'Sentiment'],
#       dtype='str')

# %% [markdown]
# **Delete unecessary Columns**

# %%
worldcup2022=worldcup2022.drop(columns='Unnamed: 0')

# %%
#check for duplicants
worldcup2022.duplicated().sum()
# Out:
# np.int64(0)

# %%
#check for missing values
worldcup2022.isnull().sum()
# Out:
# Date Created       0
# Number of Likes    0
# Source of Tweet    0
# Tweet              0
# Sentiment          0
# dtype: int64

# %% [markdown]
# **Correct Data Types**

# %%
worldcup2022['Date Created']=pd.to_datetime(worldcup2022['Date Created'])
worldcup2022.dtypes
# Out:
# Date Created       datetime64[us, UTC]
# Number of Likes                  int64
# Source of Tweet                    str
# Tweet                              str
# Sentiment                          str
# dtype: object

# %% [markdown]
# **Standardize text columns**

# %%
str_colm=worldcup2022.select_dtypes(include='str')
for col in str_colm:
    worldcup2022[col]=worldcup2022[col].str.strip().str.lower()

# %% [markdown]
# **Save a clean copy**

# %%
worldcup2022.to_csv(r"C:\Projects\worldcup-social-media-nlp\Data\worldcup2022_clean.csv")
